# %% [markdown]
# # PARTIE 2

# %% [markdown]
# ## EXO 1

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# %%
df = pd.read_csv("Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df = df.drop('Id', axis=1)

# %%
X = df.iloc[:, 0:4].values
y = df.iloc[:, 4].values

from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
y1 = encoder.fit_transform(y)
Y = pd.get_dummies(y1).values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Proposition du MODEL

# %%
model = Sequential()
model.add(Dense(4, input_shape=(4,), activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 0s 818us/step - loss: 1.5282 - accuracy: 0.3417
# Epoch 2/100
# 12/12 [==============================] - 0s 909us/step - loss: 1.4338 - accuracy: 0.3417
# Epoch 3/100
# 12/12 [==============================] - 0s 818us/step - loss: 1.3642 - accuracy: 0.3417
# Epoch 4/100
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2973 - accuracy: 0.3417
# Epoch 5/100
# 12/12 [==============================] - 0s 1ms/step - loss: 1.2501 - accuracy: 0.3417
# Epoch 6/100
# 12/12 [==============================] - 0s 727us/step - loss: 1.2046 - accuracy: 0.3417
# Epoch 7/100
# 12/12 [==============================] - 0s 727us/step - loss: 1.1733 - accuracy: 0.3417
# Epoch 8/100
# 12/12 [==============================] - 0s 909us/step - loss: 1.1413 - accuracy: 0.3417
# Epoch 9/100
# 12/12 [==============================] - 0s 818us/step - loss: 1.1150 - accuracy: 0.3417
# Epoch 10/100
# ...

# %%
y_pred = model.predict(X_test)
y_test_class = np.argmax(y_test, axis=1)
y_pred_class = np.argmax(y_pred, axis=1)
# Out:
# 1/1 [==============================] - 0s 35ms/step

# %% [markdown]
# # Amelioration Du MODEL

# %%
model2 = Sequential()
model2.add(Dense(6, input_shape=(4,), activation='relu'))

model2.add(Dense(3, activation='softmax'))
model2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model2.fit(X_train, y_train, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 1s 1ms/step - loss: 1.5066 - accuracy: 0.3250
# Epoch 2/100
# 12/12 [==============================] - 0s 727us/step - loss: 1.2676 - accuracy: 0.3250
# Epoch 3/100
# 12/12 [==============================] - 0s 909us/step - loss: 1.0990 - accuracy: 0.5583
# Epoch 4/100
# 12/12 [==============================] - 0s 910us/step - loss: 1.0067 - accuracy: 0.6583
# Epoch 5/100
# 12/12 [==============================] - 0s 818us/step - loss: 0.9686 - accuracy: 0.6583
# Epoch 6/100
# 12/12 [==============================] - 0s 818us/step - loss: 0.9473 - accuracy: 0.6583
# Epoch 7/100
# 12/12 [==============================] - 0s 818us/step - loss: 0.9344 - accuracy: 0.6583
# Epoch 8/100
# 12/12 [==============================] - 0s 818us/step - loss: 0.9216 - accuracy: 0.6667
# Epoch 9/100
# 12/12 [==============================] - 0s 910us/step - loss: 0.9096 - accuracy: 0.6667
# Epoch 10/100
# ...

# %% [markdown]
# Plus rapide et facile a réaliser

# %% [markdown]
# ## EXO 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv('data.csv')

# %%
X = dataset.iloc[:,2:32] # [all rows, col from index 2 to the last one excluding 'Unnamed: 32']
y = dataset.iloc[:,1] # [all rows, col one only which contains the classes of cancer]

# %% [markdown]
# Notice that 'diagnosis' contains 'M' or 'B' to represent Malignant or Benign tumor. Let's encode them to 0 and 1.

# %%
from sklearn.preprocessing import LabelEncoder

print("Before encoding: ")
print(y[100:110])

labelencoder_Y = LabelEncoder()
y = labelencoder_Y.fit_transform(y)

print("\nAfter encoding: ")
print(y[100:110])
# Out:
# Before encoding:
# 100    M
# 101    B
# 102    B
# 103    B
# 104    B
# 105    M
# 106    B
# 107    B
# 108    M
# 109    B
# Name: diagnosis, dtype: object
#
# After encoding:
# [1 0 0 0 0 1 0 0 1 0]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Architecture proposé

# %%
from keras.models import Sequential
from keras.layers import Dense

classifier = Sequential() # Initialising the ANN

classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 30))
classifier.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
classifier.compile(optimizer = 'rmsprop', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.fit(X_train, y_train, batch_size = 1, epochs = 100)
# Out:
# Epoch 1/100
# 455/455 [==============================] - 1s 672us/step - loss: 0.4677 - accuracy: 0.7890
# Epoch 2/100
# 455/455 [==============================] - 0s 612us/step - loss: 0.1523 - accuracy: 0.9582
# Epoch 3/100
# 455/455 [==============================] - 0s 612us/step - loss: 0.1148 - accuracy: 0.9692
# Epoch 4/100
# 455/455 [==============================] - 0s 624us/step - loss: 0.1037 - accuracy: 0.9802
# Epoch 5/100
# 455/455 [==============================] - 0s 619us/step - loss: 0.0992 - accuracy: 0.9802
# Epoch 6/100
# 455/455 [==============================] - 0s 626us/step - loss: 0.0906 - accuracy: 0.9802
# Epoch 7/100
# 455/455 [==============================] - 0s 615us/step - loss: 0.0964 - accuracy: 0.9802
# Epoch 8/100
# 455/455 [==============================] - 0s 621us/step - loss: 0.0927 - accuracy: 0.9824
# Epoch 9/100
# 455/455 [==============================] - 0s 612us/step - loss: 0.0950 - accuracy: 0.9846
# Epoch 10/100
# ...

# %% [markdown]
# ## Architecture amélioré

# %%
classifier2 = Sequential() # Initialising the ANN

classifier2.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 30))
classifier2.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
classifier2.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
classifier2.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))

classifier2.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

classifier2.compile(optimizer = 'rmsprop', loss = 'binary_crossentropy', metrics = ['accuracy'])
classifier.fit(X_train, y_train, batch_size = 1, epochs = 100)
# Out:
# Epoch 1/100
# 455/455 [==============================] - 0s 667us/step - loss: 0.0704 - accuracy: 0.9912
# Epoch 2/100
# 455/455 [==============================] - 0s 659us/step - loss: 0.0691 - accuracy: 0.9912
# Epoch 3/100
# 455/455 [==============================] - 0s 659us/step - loss: 0.0404 - accuracy: 0.9934
# Epoch 4/100
# 455/455 [==============================] - 0s 661us/step - loss: 0.0534 - accuracy: 0.9912
# Epoch 5/100
# 455/455 [==============================] - 0s 648us/step - loss: 0.0420 - accuracy: 0.9934
# Epoch 6/100
# 455/455 [==============================] - 0s 656us/step - loss: 0.0738 - accuracy: 0.9912
# Epoch 7/100
# 455/455 [==============================] - 0s 670us/step - loss: 0.0780 - accuracy: 0.9912
# Epoch 8/100
# 455/455 [==============================] - 0s 652us/step - loss: 0.0736 - accuracy: 0.9912
# Epoch 9/100
# 455/455 [==============================] - 0s 645us/step - loss: 0.0537 - accuracy: 0.9912
# Epoch 10/100
# ...

# %% [markdown]
# # EXO3

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import confusion_matrix

# %%
data = pd.read_csv('heart.csv')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
X = data.iloc[:,:13].values
y = data["target"].values

# %%
X_train,X_test,y_train, y_test = train_test_split(X,y,test_size = 0.3 , random_state = 0 )

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
classifier = Sequential()
classifier.add(Dense(activation = "relu", input_dim = 13, 
                     units = 8, kernel_initializer = "uniform"))
classifier.add(Dense(activation = "relu", units = 14, 
                     kernel_initializer = "uniform"))
classifier.add(Dense(activation = "sigmoid", units = 1, 
                     kernel_initializer = "uniform"))
classifier.compile(optimizer = 'adam' , loss = 'binary_crossentropy', 
                   metrics = ['accuracy'] )

classifier.fit(X_train , y_train , batch_size = 8 ,epochs = 100  )
# Out:
# Epoch 1/100
# 27/27 [==============================] - 0s 808us/step - loss: 0.6927 - accuracy: 0.5566
# Epoch 2/100
# 27/27 [==============================] - 0s 731us/step - loss: 0.6899 - accuracy: 0.5660
# Epoch 3/100
# 27/27 [==============================] - 0s 731us/step - loss: 0.6791 - accuracy: 0.7075
# Epoch 4/100
# 27/27 [==============================] - 0s 769us/step - loss: 0.6485 - accuracy: 0.8208
# Epoch 5/100
# 27/27 [==============================] - 0s 731us/step - loss: 0.5882 - accuracy: 0.8396
# Epoch 6/100
# 27/27 [==============================] - 0s 808us/step - loss: 0.5104 - accuracy: 0.8491
# Epoch 7/100
# 27/27 [==============================] - 0s 731us/step - loss: 0.4422 - accuracy: 0.8585
# Epoch 8/100
# 27/27 [==============================] - 0s 769us/step - loss: 0.3939 - accuracy: 0.8679
# Epoch 9/100
# 27/27 [==============================] - 0s 808us/step - loss: 0.3625 - accuracy: 0.8679
# Epoch 10/100
# ...

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
cm = confusion_matrix(y_test,y_pred)

accuracy = (cm[0][0]+cm[1][1])/(cm[0][1] + cm[1][0] +cm[0][0] +cm[1][1])
print(accuracy*100)
# Out:
# 3/3 [==============================] - 0s 998us/step
# 84.61538461538461

# %%
classifier2 = Sequential()
classifier2.add(Dense(activation = "relu", input_dim = 13, 
                     units = 8, kernel_initializer = "uniform"))
classifier2.add(Dense(activation = "relu", units = 16, 
                     kernel_initializer = "uniform"))
classifier2.add(Dropout(0.2))
classifier2.add(Dense(activation = "relu", units = 32, 
                     kernel_initializer = "uniform"))
classifier2.add(Dense(activation = "sigmoid", units = 1, 
                     kernel_initializer = "uniform"))
classifier2.compile(optimizer = 'adam' , loss = 'binary_crossentropy', 
                   metrics = ['accuracy'] )

classifier2.fit(X_train , y_train , batch_size = 8 ,epochs = 100  )
# Out:
# Epoch 1/100
# 27/27 [==============================] - 0s 808us/step - loss: 0.6931 - accuracy: 0.5330
# Epoch 2/100
# 27/27 [==============================] - 0s 769us/step - loss: 0.6922 - accuracy: 0.5566
# Epoch 3/100
# 27/27 [==============================] - 0s 769us/step - loss: 0.6847 - accuracy: 0.7877
# Epoch 4/100
# 27/27 [==============================] - 0s 846us/step - loss: 0.6419 - accuracy: 0.8160
# Epoch 5/100
# 27/27 [==============================] - 0s 846us/step - loss: 0.5511 - accuracy: 0.8443
# Epoch 6/100
# 27/27 [==============================] - 0s 846us/step - loss: 0.4913 - accuracy: 0.8585
# Epoch 7/100
# 27/27 [==============================] - 0s 808us/step - loss: 0.4364 - accuracy: 0.8679
# Epoch 8/100
# 27/27 [==============================] - 0s 769us/step - loss: 0.3870 - accuracy: 0.8585
# Epoch 9/100
# 27/27 [==============================] - 0s 808us/step - loss: 0.3506 - accuracy: 0.8679
# Epoch 10/100
# ...

# %%
y_pred = classifier2.predict(X_test)
y_pred = (y_pred > 0.5)
cm = confusion_matrix(y_test,y_pred)

accuracy = (cm[0][0]+cm[1][1])/(cm[0][1] + cm[1][0] +cm[0][0] +cm[1][1])
print(accuracy*100)
# Out:
# 3/3 [==============================] - 0s 2ms/step
# 85.71428571428571
