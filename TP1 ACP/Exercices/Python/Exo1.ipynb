# %%
import numpy as np
# Génération de données selon une loi normale tridimensionnelle
rndn3d = np.random.randn(500,3)

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Affichage du nuage de points
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(rndn3d[:,0], rndn3d[:,1], rndn3d[:,2])
plt.title("Données initiales")
plt.show()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=3)
pca.fit(rndn3d)

print("Pourcentage de variance expliquée : ")
print(pca.explained_variance_ratio_)
print("Composantes principales : ")
print(pca.components_)
# Out:
# Pourcentage de variance expliquée :
# [0.35367933 0.34051724 0.30580342]
# Composantes principales :
# [[ 0.64839259  0.58965664  0.48155175]
#  [ 0.75948531 -0.54472176 -0.35561253]
#  [ 0.05262243  0.59630801 -0.80102911]]

# %%
rndn3d = np.random.randn(500,3)


pca = PCA(n_components=3)
pca.fit(rndn3d)

print("Pourcentage de variance expliquée : ")
print(pca.explained_variance_ratio_)
print("Composantes principales : ")
print(pca.components_)
# Out:
# Pourcentage de variance expliquée :
# [0.37041465 0.33846116 0.2911242 ]
# Composantes principales :
# [[-0.33533705 -0.28974518 -0.8964356 ]
#  [-0.12475534 -0.92949381  0.34709848]
#  [-0.93380146  0.22823012  0.27554646]]

# %% [markdown]
# il y a une difference entre le premier table et le deuxieme, ce sont des données aléatoires

# %%
s1 = np.array([[3,0,0],[0,1,0],[0,0,0.2]])  # matrice de déformation
r1 = np.array([[0.36,0.48,-0.8],[-0.8,0.6,0],[0.48,0.64,0.6]])  # matrice de rotation
rndef = rndn3d.dot(s1).dot(r1)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(rndef[:,0], rndef[:,1], rndef[:,2])
plt.title("Données déformées")
plt.show()
